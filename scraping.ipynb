# %%
import requests
import json
import pandas as pd
import numpy as np
import time

from newsapi import NewsApiClient

# %%
newsapi = NewsApiClient(api_key='360c32b12d8449b683c6916409ab2042')

# %%
test = newsapi.get_everything(sources='fox-news', page_size=10)

# %%
test['articles'][0]
# Out:
# {'source': {'id': 'fox-news', 'name': 'Fox News'},
#  'author': None,
#  'title': 'Sen. Lankford: Asylum process needs to be faster',
#  'description': 'Republican senator from Oklahoma calls for keeping families together, pushes Congress to fix immigration system.',
#  'url': 'http://video.foxnews.com/v/5799399622001/',
#  'urlToImage': 'http://a57.foxnews.com/media2.foxnews.com/BrightCove/694940094001/2018/06/19/640/360/694940094001_5799405663001_5799399622001-vs.jpg',
#  'publishedAt': '2018-06-19T18:30:52Z'}

# %%
articles = []
for i in range(1,99):
    news = newsapi.get_everything(sources='fox-news,breitbart-news,national-review',
#                            from_parameter='2018-01-19',
#                            to='2018-06-19',
                           language='en',
                           sort_by='publishedAt',
                           page_size=100,
                           page = i)
    for n in range(0,99):
        articles.append(news['articles'][n])

# %%
articles = pd.DataFrame(articles)

# %%
len(articles['title'].unique())
# Out:
# 9631

# %%
articles.to_csv('./con_articles.csv')

# %% [markdown]
# ------------------------------------------------------------

# %%
fox_posts = []
for i in range(1,51):
    news = newsapi.get_everything(sources='fox-news',
                           language='en',
                           sort_by='publishedAt',
                           page_size=100,
                           page = i)
    for n in range(0,99):
        fox_posts.append(news['articles'][n])
# Out:
# ---------------------------------------------------------------------------
# NewsAPIException                          Traceback (most recent call last)
# <ipython-input-48-c2dd683a0927> in <module>()
#       5                            sort_by='publishedAt',
#       6                            page_size=100,
# ----> 7                            page = i)
#       8     for n in range(0,99):
#       9         fox_posts.append(news['articles'][n])
#
# /anaconda3/envs/dsi/lib/python3.6/site-packages/newsapi/newsapi_client.py in get_everything(self, q, sources, domains, from_param, to, language, sort_by, page, page_size)
#     250         # Check Status of Request
#     251         if r.status_code != requests.codes.ok:
# --> 252             raise NewsAPIException(r.json())
#     253
#     254         return r.json()
#
# ...

# %%
fox_posts = pd.DataFrame(fox_posts)

# %%
fox_posts.to_csv('./fox_posts.csv')

# %%
len(fox_posts['title'].unique())
# Out:
# 21

# %%
# All recent Breitbart articles
url='https://newsapi.org/v2/everything?sources=breitbart-news&apiKey=360c32b12d8449b683c6916409ab2042'
headers = {'User-agent': 'Con bot 0.1'}
res = requests.get(url, headers=headers)
res.status_code
# Out:
# 200

# %%
fox_posts.shape
# Out:
# (4000, 7)

# %%
fox_posts.head(2)
# Out:
#   author                                        description  \
# 0   None  'MediaBuzz' host Howard Kurtz weighs in on how...
# 1   None  Republican senator from Louisiana asks the ins...
#
#             publishedAt                                  source  \
# 0  2018-06-18T21:02:24Z  {'id': 'fox-news', 'name': 'Fox News'}
# 1  2018-06-18T20:53:17Z  {'id': 'fox-news', 'name': 'Fox News'}
#
#                                                title  \
# 0  Kurtz: How images of crying children turned th...
# 1  Sen. Kennedy challenges Horowitz over findings...
#
#                                          url  \
# 0  http://video.foxnews.com/v/5798979329001/
# 1  http://video.foxnews.com/v/5798980292001/
#
#                                           urlToImage
# 0  http://a57.foxnews.com/media2.foxnews.com/Brig...
# 1  http://a57.foxnews.com/media2.foxnews.com/Brig...

# %%
len(fox_posts['title'].unique())
# Out:
# 23

# %%
fox_posts
# Out:
#                   author                                        description  \
# 0                   None  'MediaBuzz' host Howard Kurtz weighs in on how...
# 1                   None  Republican senator from Louisiana asks the ins...
# 2       Associated Press  There are over 1 billion firearms in the world...
# 3       Associated Press  A Turkish court has accepted an indictment cha...
# 4                   None  Emilia Clarke paid tribute to HBO's 'Game of T...
# 5               Gregg Re  Fox News Senate Judiciary Chair Grassley calls...
# 6       Associated Press  Uncertainty loomed over Colombia's fragile pea...
# 7        Alexandria Hein  A clinical trial currently underway at the Cle...
# 8           James Rogers  A mysterious inscription from the 7th-century ...
# 9          Zoe Szathmary  The Montana Fish, Wildlife and Parks (FWP) rev...
# 10                  None  Inspector general Michael Horowitz testifies b...
# ...

# %% [markdown]
# -------------------------------------

# %%
bb = res.json()
bb
# Out:
# {'status': 'ok',
#  'totalResults': 21519,
#  'articles': [{'source': {'id': 'breitbart-news', 'name': 'Breitbart News'},
#    'author': 'Joel B. Pollak',
#    'title': 'Kamala Harris: Homeland Security Secretary Nielsen Should Resign',
#    'description': 'Sen. Kamala Harris (D-CA), a leading contender for the Democratic Party nomination for president in 2020, said Monday that Secretary of Homeland Security Kirstjen Nielsen should resign over the enforcement of immigration law at the border, which has resulted …',
#    'url': 'http://www.breitbart.com/big-government/2018/06/18/kamala-harris-homeland-security-secretary-nielsen-should-resign/',
#    'urlToImage': 'http://media.breitbart.com/media/2018/05/GettyImages-961761456.jpg',
#    'publishedAt': '2018-06-18T20:48:29Z'},
#   {'source': {'id': 'breitbart-news', 'name': 'Breitbart News'},
#    'author': 'Jerome Hudson',
# ...

# %%
bb_posts = []
after = None
for i in range(200):
    if i % 20 == 0:
        print('{} of 200'.format(i)) 
    if after == None:
        params = {}
    else: 
        params = {'after': after}
    res = requests.get(url, params=params, headers=headers)
    if res.status_code == 200:
        posts = res.json()
        bb_posts.extend(posts['articles'])
        after = bb['articles'][-1]['publishedAt']
    else:
        print(res.status_code)
        break
    time.sleep(3)
# Out:
# 0 of 200
# 20 of 200
# 40 of 200
# 60 of 200
# 80 of 200
# 100 of 200
# 120 of 200
# 140 of 200
# 160 of 200
# 180 of 200

# %%
bb_posts = pd.DataFrame(bb_posts)

# %%
bb_posts.to_csv('./bb_posts.csv')

# %%
len(bb_posts['title'].unique())
# Out:
# 20

# %% [markdown]
# ____________________________________________________________

# %%
# All recent NR articles
url='https://newsapi.org/v2/everything?sources=national-review&apiKey=360c32b12d8449b683c6916409ab2042'
headers = {'User-agent': 'Con bot 0.1'}
res = requests.get(url, headers=headers)
res.status_code
# Out:
# 200

# %%
nr = res.json()

# %%
nr.keys()
# Out:
# dict_keys(['status', 'totalResults', 'articles'])

# %%
nr['articles'][0].keys()
# Out:
# dict_keys(['source', 'author', 'title', 'description', 'url', 'urlToImage', 'publishedAt'])

# %%
len(nr['articles'])
# Out:
# 20

# %%
nr['articles'][0]['publishedAt']
# Out:
# '2018-06-18T20:52:42Z'

# %%
nr_posts = []
after = None
for i in range(200):
    if i % 20 == 0:
        print('{} of 200'.format(i)) 
    if after == None:
        params = {}
    else: 
        params = {'after': after}
    res = requests.get(url, params=params, headers=headers)
    if res.status_code == 200:
        posts = res.json()
        nr_posts.extend(posts['articles'])
        after = nr['articles'][-1]['publishedAt']
    else:
        print(res.status_code)
        break
    time.sleep(3)
# Out:
# 0 of 200
# 20 of 200
# 40 of 200
# 60 of 200
# 80 of 200
# 100 of 200
# 120 of 200
# 140 of 200
# 160 of 200
# 180 of 200

# %%
nr_posts = pd.DataFrame(nr_posts)

# %%
nr_posts.to_csv('./nr_posts.csv')

# %%
nr_posts
# Out:
#                   author                                        description  \
# 0           David French        It’s time for legislative impotence to end.
# 1         Jason Richwine  The lawsuit alleging anti-Asian discrimination...
# 2                   None                                       How dare he.
# 3     Andrew C. McCarthy  The political calendar should never dictate ho...
# 4             Rich Lowry  This is not how the policy is supposed to work...
# 5         Jonah Goldberg  Forbes has what looks like a blockbuster repor...
# 6             Jack Crowe  ICE defended forensic analyst Justin Gaertner ...
# 7         Douglas Murray  The Southern Poverty Law Center pays millions ...
# 8        National Review  David and Will discuss discuss Gavin Newsom’s ...
# 9        Mairead McArdle  'Our destiny beyond the Earth is not only a ma...
# 10       Carrie Severino  Here is this week’s update on federal judicial...
# ...
